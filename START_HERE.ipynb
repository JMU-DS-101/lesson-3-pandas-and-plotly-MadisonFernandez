# %% [markdown]
# # Welcome to DS 101: Introduction to Data Science
#
# **You are in the right place.** This notebook will get you set up and ready to start Lesson 3.

# %% [markdown]
# ## Lesson 3 Overview: Data Wrangling with Pandas
#
# In this lesson you will work with a real dataset — Reddit posts from the r/JMU subreddit — and learn how to:
#
# | Step | What you will do |
# |------|------------------|
# | 1 | **Load data** from a CSV file into Python |
# | 2 | **Explore** the structure and contents of the dataset |
# | 3 | **Clean** the data (handle missing values, fix column types) |
# | 4 | **Visualize** the data using interactive charts |
#
# No prior experience with pandas is required. Everything is explained step by step.

# %% [markdown]
# ## Quick Start: 3 Steps to Begin
#
# ### Step 1 — Verify your environment
# Run the cell below (click it, then press **Shift + Enter**). You should see a green checkmark for each package. If you see any errors, let your instructor know.

# %%
# Environment check — run this first!
import sys

checks = {
    "pandas": "Data manipulation",
    "plotly": "Interactive charts",
}

all_ok = True
for package, description in checks.items():
    try:
        __import__(package)
        print(f"  ✅ {package} — {description}")
    except ImportError:
        print(f"  ❌ {package} — NOT FOUND (contact your instructor)")
        all_ok = False

print()
print(f"  Python version: {sys.version.split()[0]}")
print()
if all_ok:
    print("✅ Your environment is ready! Proceed to Step 2.")
else:
    print("❌ One or more packages are missing. Please contact your instructor.")

# %% [markdown]
# ### Step 2 — Open the lesson notebook
#
# In the **file explorer on the left**, open:
#
# ```
# lesson_3_introduction_pandas/
#   └── lesson 3_introduction_pandas_datawrangling.ipynb
# ```
#
# Double-click the file to open it.

# %% [markdown]
# ### Step 3 — Select the Python kernel
#
# When the lesson notebook opens, you may be asked to select a kernel (the Python engine that runs your code).
#
# - Click **Select Kernel** in the top-right corner of the notebook
# - Choose **Python 3.11** (it will say something like `Python 3.11.x`)
#
# You are now ready to start the lesson. Work through the cells from top to bottom using **Shift + Enter** to run each one.

# %% [markdown]
# ---
#
# ## Helpful Tips
#
# | Shortcut | Action |
# |----------|--------|
# | **Shift + Enter** | Run the current cell and move to the next |
# | **Ctrl + Enter** | Run the current cell and stay |
# | **Esc then A** | Insert a new cell above |
# | **Esc then B** | Insert a new cell below |
# | **Esc then D D** | Delete the current cell |
#
# > **Tip:** If something goes wrong and your notebook gets stuck, go to **Kernel → Restart Kernel** in the menu bar and run the cells again from the top.
